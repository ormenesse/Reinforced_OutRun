# %%
from functions import *
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
import mss
import sched, time
import cv2
import time
from tqdm import tqdm
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import re

# %%
import pytesseract

# %%
import subprocess
import pyautogui

def generate_emulator_pid():

    p = subprocess.Popen(['gens','/home/ormenesse/Documents/Reinforced_Outrun/OutRun (USA, Europe).md'])
    
    time.sleep(0.5)
        
    # you gotta have xdotool installed in your machine
    
    output = subprocess.check_output(['xdotool','search','--pid',str(p.pid)])
    xw_id = re.findall('(\d+)',str(output))[1]
    output = subprocess.run(['xwininfo','-id',xw_id],stdout=subprocess.PIPE)
    output = output.stdout.decode('utf-8')
    print(output)
    #get screens positions

    upperleftx = int(re.findall('upper-left X:\s+(\d+)',output)[0])
    upperlefty = int(re.findall('upper-left Y:\s+(\d+)',output)[0])

    # load quick save state
    time.sleep(0.15)
    pyautogui.press('f8')

    return p, upperleftx, upperlefty

def kill_process(p):

    p.kill()

# %%
def capture(graber,positionx,positiony):

    #print("Comecando a gavar...")
    sct_img = graber.grab({'left': positionx, 'top': positiony+40, 'width': 640, 'height': 446})
    Img = Image.frombytes('RGB', sct_img.size, sct_img.bgra, 'raw', 'BGRX')
    Img.thumbnail((320,220), Image.ANTIALIAS)
    Img = np.array(Img.convert('L')).astype(np.uint8)
    #Img = Img.T
    return Img

# %%
graber = mss.mss()

# %%
p, x, y = generate_emulator_pid()
img = capture(graber,x,y)
# Out:
# xwininfo: Window id: 0x4e00003 "Gens/GS r7 - Genesis: OUTRUN"
#
#   Absolute upper-left X:  363
#   Absolute upper-left Y:  156
#   Relative upper-left X:  3
#   Relative upper-left Y:  24
#   Width: 640
#   Height: 503
#   Depth: 24
#   Visual: 0x21
#   Visual Class: TrueColor
#   Border width: 0
#   Class: InputOutput
#   Colormap: 0x20 (installed)
#   Bit Gravity State: NorthWestGravity
#   Window Gravity State: NorthWestGravity
#   Backing Store State: NotUseful
#   Save Under State: no
#   Map State: IsViewable
#   Override Redirect State: no
#   Corners:  +363+156  -357+156  -357-109  +363-109
#   -geometry 640x503+360+132
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-d0ada1af8831> in <module>
# ----> 1 p, x, y = generate_emulator_pid()
#       2 img = capture(graber,x,y)
#
# <ipython-input-71-1b53e2dca90d> in generate_emulator_pid()
#      18
#      19     upperleftx = int(re.findall('upper-left X:\s+(\d+)',output)[0])
# ---> 20     upperlefty = int(re.findall('upper-left y:\s+(\d+)',output)[0])
#      21
#      22     # load quick save state
#
# IndexError: list index out of range

# %%
img = capture(graber,x,y)

# %%
#plt.figure(figsize=(10,10))
plt.imshow(img,cmap='gray', vmin=0, vmax=255)

# %%
img.shape
# Out:
# (220, 315)

# %%
plt.imshow(img[12:27,130:200],cmap='gray', vmin=0, vmax=255)

# %%
pytesseract.image_to_string(img[12:27,130:200],nice=1,config='--psm 8 --oem 3 outputbase digits')
# Out:
# '00000000'

# %%
plt.imshow(img[21:40,15:41])

# %%
pytesseract.image_to_string(img[21:40,15:41],nice=1,config='--psm 8 --oem 3 outputbase digits')
# Out:
# '000'
