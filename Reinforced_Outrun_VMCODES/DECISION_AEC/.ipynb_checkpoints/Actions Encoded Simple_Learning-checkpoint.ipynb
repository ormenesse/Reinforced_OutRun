# %%
import pandas as pd
import numpy as np
import cv2
import pickle

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import gc
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import roc_curve

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from time import time
import keras
import keras.backend as K
from keras import metrics
from keras.engine.topology import Layer, InputSpec
from keras.layers import Dense, Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Lambda
from keras.models import Model
from keras.optimizers import SGD
from keras import callbacks
from keras.initializers import VarianceScaling
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, Concatenate, Flatten, Reshape
from keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from keras.metrics import binary_accuracy
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf

# %%
def load_file(nome_arquivo):
    with open(nome_arquivo, 'rb') as input:
        objeto = pickle.load(input)
    return objeto

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#comandos = pd.concat([pd.DataFrame(load_file('/content/drive/My Drive/Colab Notebooks/comando_new.pkl')),\
#          pd.DataFrame(load_file('/content/drive/My Drive/Colab Notebooks/img_new.pkl'))],\
#          axis=0)
comandos = pd.DataFrame(load_file('/content/drive/My Drive/Colab Notebooks/comando_new.pkl'))

# %%
comandos.describe()
# Out:
#                  0            1            2            3
# count  3402.000000  3402.000000  3402.000000  3402.000000
# mean     -0.002646     0.000294     0.235156     0.013521
# std       0.359267     0.038341     0.424158     0.115510
# min      -1.000000    -1.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000

# %%
comandos['direita'] = comandos[0].map(lambda x: 1 if x == 1 else 0)
comandos['esquerda'] = comandos[0].map(lambda x: 1 if x == -1 else 0)
comandos['baixo'] = comandos[1].map(lambda x: 1 if x == 1 else 0)
comandos['cima'] = comandos[1].map(lambda x: 1 if x == -1 else 0)

# %%
comandos = comandos[[2,3,'direita','esquerda','cima','baixo']].rename(index=str, columns={2:'acelera',3:'freia'})

# %%
"""
imagens = []
for img in load_file('/content/drive/My Drive/Colab Notebooks/img.pkl'):
  imagens.append(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)/255)
for img in load_file('/content/drive/My Drive/Colab Notebooks/img2.pkl'):
  imagens.append(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)/255)
"""
imagens = load_file('/content/drive/My Drive/Colab Notebooks/img_new.pkl')

# %%
len(imagens)
# Out:
# 3402

# %%
imagens = np.array(imagens).astype(np.uint8)

# %%
imagens.shape
# Out:
# (3402, 3, 220, 320)

# %%
imagens =  np.swapaxes(imagens,1,2)
imagens =  np.swapaxes(imagens,2,3)

# %%
imagens.shape
# Out:
# (3402, 220, 320, 3)

# %% [markdown]
# Arrumando Comandos

# %%
com = 100000*comandos['acelera']+10000*comandos['freia']+1000*comandos['direita']+100*comandos['esquerda']+10*comandos['cima']+comandos['baixo']

# %%
com = pd.get_dummies(com)

# %%
com.describe()
# Out:
#             0            100     ...       110100       111000
# count  3402.000000  3402.000000  ...  3402.000000  3402.000000
# mean      0.750441     0.003233  ...     0.003233     0.004115
# std       0.432821     0.056779  ...     0.056779     0.064027
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       1.000000     0.000000  ...     0.000000     0.000000
# 50%       1.000000     0.000000  ...     0.000000     0.000000
# 75%       1.000000     0.000000  ...     0.000000     0.000000
# max       1.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 14 columns]

# %%
gc.collect()
# Out:
# 22

# %%
com.shape[1]
# Out:
# 14

# %%
#input_shape = (img_rows, img_cols, 1)
input_shape = (220, 320, 3)
num_classes = com.shape[1]
batch_size = 64
epochs = 60 #600

# %%
# CRIANDO MODELO

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Lambda(lambda x: x/255,input_shape=input_shape))
model.add(tf.keras.layers.Conv2D(128, kernel_size=(5, 5), strides=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Conv2D(128, kernel_size=(5, 5), strides=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(5, 5), strides=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1024, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))
#model.add(tf.keras.layers.Dense(num_classes))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_3 (Lambda)            (None, 220, 320, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 108, 158, 128)     9728
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 108, 158, 128)     512
# _________________________________________________________________
# activation_9 (Activation)    (None, 108, 158, 128)     0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 108, 158, 128)     0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 54, 79, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 25, 38, 128)       409728
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 25, 38, 128)       512
# _________________________________________________________________
# activation_10 (Activation)   (None, 25, 38, 128)       0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 25, 38, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 11, 17, 64)        204864
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 11, 17, 64)        256
# _________________________________________________________________
# activation_11 (Activation)   (None, 11, 17, 64)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 11, 17, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 8, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2560)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1024)              2622464
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 14)                238
# =================================================================
# Total params: 3,840,830
# Trainable params: 3,840,190
# Non-trainable params: 640
# _________________________________________________________________

# %%
# train, test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(range(0,comandos.shape[0]),range(0,comandos.shape[0]), test_size=0.1, random_state=42)

# %%
#model.compile(loss=keras.losses.binary_crossentropy,
#              optimizer=keras.optimizers.Adam(lr=INIT_LR, decay=INIT_LR / epochs),
#              metrics=['accuracy'])
INIT_LR = 1e-3
model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer='adam',
              metrics=['acc'])

# %%
imagens[X_train,:,:,:].shape,com.shape
# Out:
# ((3061, 220, 320, 3), (3402, 14))

# %%
earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20,verbose=0, mode='min')
mcp_save = tf.keras.callbacks.ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/modelo_outrun_encoded_learning_best.hdf5', save_best_only=True, monitor='val_loss', mode='auto')
reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, min_delta=1e-4, mode='auto')
#imagens[X_train,:,:,:] imagens[X_test,:,:,:]
model.fit(imagens[X_train,:,:,:], com.iloc[X_train].values,
          batch_size=batch_size,
          epochs=epochs,
          shuffle = True,
          validation_data=(imagens[X_test,:,:,:], com.iloc[X_test].values))
score = model.evaluate(imagens[X_test,:,:,:], com.iloc[X_test].values, verbose=0)
print('Test loss:', score[0])
# Out:
# Epoch 1/60
# 48/48 [==============================] - 4s 92ms/step - loss: 3.1223 - acc: 0.4152 - val_loss: 2.3464 - val_acc: 0.7009
# Epoch 2/60
# 48/48 [==============================] - 4s 89ms/step - loss: 2.0906 - acc: 0.5420 - val_loss: 2.1027 - val_acc: 0.7009
# Epoch 3/60
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7415 - acc: 0.6736 - val_loss: 2.0958 - val_acc: 0.7009
# Epoch 4/60
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5406 - acc: 0.7014 - val_loss: 2.0755 - val_acc: 0.7009
# Epoch 5/60
# 48/48 [==============================] - 4s 88ms/step - loss: 1.4111 - acc: 0.7262 - val_loss: 1.8959 - val_acc: 0.7009
# Epoch 6/60
# 48/48 [==============================] - 4s 88ms/step - loss: 1.2960 - acc: 0.7416 - val_loss: 1.7871 - val_acc: 0.7009
# Epoch 7/60
# 48/48 [==============================] - 4s 88ms/step - loss: 1.2616 - acc: 0.7393 - val_loss: 1.7095 - val_acc: 0.7009
# Epoch 8/60
# 48/48 [==============================] - 4s 88ms/step - loss: 1.1563 - acc: 0.7386 - val_loss: 1.2429 - val_acc: 0.7009
# Epoch 9/60
# 48/48 [==============================] - 4s 89ms/step - loss: 1.1123 - acc: 0.7377 - val_loss: 1.5031 - val_acc: 0.7009
# Epoch 10/60
# 48/48 [==============================] - 4s 89ms/step - loss: 1.0879 - acc: 0.7337 - val_loss: 1.2028 - val_acc: 0.7009
# Epoch 11/60
# 48/48 [==============================] - 4s 88ms/step - loss: 1.0841 - acc: 0.7393 - val_loss: 1.1992 - val_acc: 0.7009
# Epoch 12/60
# 48/48 [==============================] - 4s 88ms/step - loss: 1.0391 - acc: 0.7471 - val_loss: 1.1462 - val_acc: 0.7009
# Epoch 13/60
# 48/48 [==============================] - 4s 89ms/step - loss: 1.0125 - acc: 0.7533 - val_loss: 1.0241 - val_acc: 0.7009
# Epoch 14/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.9777 - acc: 0.7560 - val_loss: 1.0668 - val_acc: 0.7009
# Epoch 15/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.9882 - acc: 0.7540 - val_loss: 1.0883 - val_acc: 0.7009
# Epoch 16/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.9595 - acc: 0.7547 - val_loss: 0.9755 - val_acc: 0.7009
# Epoch 17/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.9350 - acc: 0.7556 - val_loss: 0.9701 - val_acc: 0.7009
# Epoch 18/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.9398 - acc: 0.7566 - val_loss: 0.9950 - val_acc: 0.7009
# Epoch 19/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.9094 - acc: 0.7563 - val_loss: 0.9491 - val_acc: 0.7009
# Epoch 20/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.9154 - acc: 0.7566 - val_loss: 1.0924 - val_acc: 0.7009
# Epoch 21/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8836 - acc: 0.7560 - val_loss: 0.9865 - val_acc: 0.7009
# Epoch 22/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8791 - acc: 0.7560 - val_loss: 1.0721 - val_acc: 0.7009
# Epoch 23/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.8902 - acc: 0.7563 - val_loss: 0.9589 - val_acc: 0.7009
# Epoch 24/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8769 - acc: 0.7589 - val_loss: 0.9681 - val_acc: 0.7009
# Epoch 25/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8599 - acc: 0.7563 - val_loss: 0.9591 - val_acc: 0.7009
# Epoch 26/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8658 - acc: 0.7563 - val_loss: 0.9474 - val_acc: 0.7009
# Epoch 27/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8767 - acc: 0.7586 - val_loss: 0.9362 - val_acc: 0.7009
# Epoch 28/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8566 - acc: 0.7566 - val_loss: 1.1050 - val_acc: 0.7009
# Epoch 29/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8548 - acc: 0.7599 - val_loss: 1.2523 - val_acc: 0.7009
# Epoch 30/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8605 - acc: 0.7605 - val_loss: 0.9233 - val_acc: 0.7009
# Epoch 31/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8226 - acc: 0.7602 - val_loss: 1.1811 - val_acc: 0.7009
# Epoch 32/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8256 - acc: 0.7579 - val_loss: 0.9430 - val_acc: 0.7009
# Epoch 33/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8161 - acc: 0.7582 - val_loss: 0.9358 - val_acc: 0.7009
# Epoch 34/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8161 - acc: 0.7586 - val_loss: 0.9180 - val_acc: 0.7009
# Epoch 35/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8229 - acc: 0.7599 - val_loss: 1.0250 - val_acc: 0.7009
# Epoch 36/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8186 - acc: 0.7596 - val_loss: 0.9414 - val_acc: 0.7009
# Epoch 37/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7897 - acc: 0.7615 - val_loss: 1.0037 - val_acc: 0.7009
# Epoch 38/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7888 - acc: 0.7615 - val_loss: 0.9565 - val_acc: 0.7009
# Epoch 39/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7861 - acc: 0.7599 - val_loss: 0.9205 - val_acc: 0.7009
# Epoch 40/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7863 - acc: 0.7605 - val_loss: 0.9433 - val_acc: 0.7009
# Epoch 41/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.8156 - acc: 0.7582 - val_loss: 1.0745 - val_acc: 0.7009
# Epoch 42/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7532 - acc: 0.7618 - val_loss: 1.0318 - val_acc: 0.7009
# Epoch 43/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7716 - acc: 0.7628 - val_loss: 0.9271 - val_acc: 0.7009
# Epoch 44/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7420 - acc: 0.7628 - val_loss: 0.9562 - val_acc: 0.7009
# Epoch 45/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7490 - acc: 0.7625 - val_loss: 0.9081 - val_acc: 0.7009
# Epoch 46/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.7475 - acc: 0.7622 - val_loss: 0.9946 - val_acc: 0.7243
# Epoch 47/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.7352 - acc: 0.7687 - val_loss: 1.0202 - val_acc: 0.7243
# Epoch 48/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7553 - acc: 0.7658 - val_loss: 0.8849 - val_acc: 0.7214
# Epoch 49/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7297 - acc: 0.7667 - val_loss: 0.9302 - val_acc: 0.7126
# Epoch 50/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7218 - acc: 0.7680 - val_loss: 0.8613 - val_acc: 0.7243
# Epoch 51/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.7301 - acc: 0.7694 - val_loss: 0.9256 - val_acc: 0.7097
# Epoch 52/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7214 - acc: 0.7716 - val_loss: 0.8610 - val_acc: 0.7009
# Epoch 53/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7029 - acc: 0.7723 - val_loss: 0.8468 - val_acc: 0.7273
# Epoch 54/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7034 - acc: 0.7729 - val_loss: 1.0796 - val_acc: 0.7185
# Epoch 55/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.7389 - acc: 0.7703 - val_loss: 0.9871 - val_acc: 0.7214
# Epoch 56/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.6845 - acc: 0.7743 - val_loss: 1.4275 - val_acc: 0.7009
# Epoch 57/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.6681 - acc: 0.7762 - val_loss: 0.9565 - val_acc: 0.7331
# Epoch 58/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.6995 - acc: 0.7769 - val_loss: 0.9354 - val_acc: 0.7214
# Epoch 59/60
# 48/48 [==============================] - 4s 89ms/step - loss: 0.6772 - acc: 0.7792 - val_loss: 0.8524 - val_acc: 0.7390
# Epoch 60/60
# 48/48 [==============================] - 4s 88ms/step - loss: 0.6414 - acc: 0.7818 - val_loss: 1.0679 - val_acc: 0.6481
# Test loss: 1.0491055250167847

# %%
model.save_weights("/content/drive/My Drive/Colab Notebooks/model_3_encoded_learning_final.hdf5")
model.save("/content/drive/My Drive/Colab Notebooks/model_3_encoded_learning.model")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/model_3_encoded_learning.model/assets
