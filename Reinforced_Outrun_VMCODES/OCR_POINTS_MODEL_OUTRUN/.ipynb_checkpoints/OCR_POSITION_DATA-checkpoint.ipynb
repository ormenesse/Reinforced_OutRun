# %% [markdown]
# # Position Model Analysis

# %%
import pandas as pd
import numpy as np
import cv2
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import pytesseract
import glob
import re
from IPython.display import display, clear_output
from tqdm import tqdm

# %%
def save_to_file(objeto, nome_arquivo):
    with open(nome_arquivo, 'wb') as output:
        pickle.dump(objeto, output, pickle.HIGHEST_PROTOCOL)


def load_file(nome_arquivo):
    with open(nome_arquivo, 'rb') as input:
        objeto = pickle.load(input)
    return objeto

# %%
list_of_files = glob.glob("../ANALYSE_DATA/fila_primeiro_treino*")

# %%
list_of_files.append('../ANALYSE_DATA/fila_treino_362.0_23.pkl')
list_of_files.append('../ANALYSE_DATA/fila_treino_362.0_30.pkl')

# %%
list_of_files
# Out:
# ['../ANALYSE_DATA/fila_primeiro_treino.pkl',
#  '../ANALYSE_DATA/fila_primeiro_treino_2.pkl',
#  '../ANALYSE_DATA/fila_treino_362.0_23.pkl',
#  '../ANALYSE_DATA/fila_treino_362.0_30.pkl']

# %% [markdown]
# LOADING FILES AND WORKING WITH IT

# %% [markdown]
# 8 px between each number

# %% [markdown]
# 1 - Bom - 0 Ruim

# %%
vector_img = {}

# %%
for file in list_of_files:
    if 'fila_treino' in file:
        load = load_file(file)
        print('Tamanho Treino:',len(load))
        for i in np.random.randint(0,len(load),size=(400)):
            
            clear_output(wait=True)
            plt.imshow(load[i][0][140:,50:250])
            display(plt.show())

            img = load[i][0].copy()

            ihash_1 = hash(img[140:,50:250].tobytes())

            try:
                display(print('valor 1 salvo:',vector_img[ihash_1][1]))
            except:
                number = input('Digite para o valor 1: ')
                if number == '0':
                    vector_img[ihash_1] = (img[140:,50:250].copy(),int(number))
                else:
                    vector_img[ihash_1] = (img[140:,50:250].copy(),int('1'))
# Out:
# None
# Digite para o valor 1:

# %%
len(vector_img.keys())
# Out:
# 659

# %%
save_to_file(vector_img, 'train_images_outrun_position_Score.pkl')

# %%
vector_img = load_file('train_images_outrun_position_Score.pkl')

# %%
load = load_file('../ANALYSE_DATA/fila_primeiro_treino.pkl')
print('Tamanho Treino:',len(load))
for i in np.random.randint(0,len(load),size=(300)):

    clear_output(wait=True)
    plt.imshow(load[i][0][140:,50:250])
    display(plt.show())

    img = load[i][0].copy()

    ihash_1 = hash(img[140:,50:250].tobytes())

    try:
        display(print('valor 1 salvo:',vector_img[ihash_1][1]))
    except:
        number = input('Digite para o valor 1: ')
        if number == '0':
            vector_img[ihash_1] = (img[140:,50:250].copy(),int(number))
        else:
            vector_img[ihash_1] = (img[140:,50:250].copy(),int('1'))
# Out:
# None
# Digite para o valor 1:

# %%
save_to_file(vector_img, 'train_images_outrun_position_Score.pkl')

# %%
len(vector_img.keys())
# Out:
# 1208
