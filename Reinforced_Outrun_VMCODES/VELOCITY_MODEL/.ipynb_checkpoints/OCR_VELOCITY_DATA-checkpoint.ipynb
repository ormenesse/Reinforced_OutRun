# %%
import pandas as pd
import numpy as np
import cv2
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import pytesseract
import glob
import re
from IPython.display import display, clear_output

# %%
def save_to_file(objeto, nome_arquivo):
    with open(nome_arquivo, 'wb') as output:
        pickle.dump(objeto, output, pickle.HIGHEST_PROTOCOL)


def load_file(nome_arquivo):
    with open(nome_arquivo, 'rb') as input:
        objeto = pickle.load(input)
    return objeto

# %%
def process_img(image, sigma=0.4):
	# compute the median of the single channel pixel intensities
    v = np.median(image)
    # apply automatic Canny edge detection using the computed median
    lower = int(max(0, (1.0 - sigma) * v))
    upper = int(min(255, (1.0 + sigma) * v))
    edged = cv2.Canny(image, lower, upper)
    # return the edged image
    return edged

# %%
list_of_files = glob.glob("../ANALYSE_DATA/*.pkl")

# %% [markdown]
# LOADING FILES AND WORKING WITH IT

# %% [markdown]
# 8 px between each number

# %%
limit_numbers_1 = np.arange(17,41,8)
limit_numbers_2 = np.arange(25,49,8)

# %%
vector_img = {}

# %%
list_of_files.reverse()

# %%
 for file in list_of_files:
    if 'fila_treino' in file:
        load = load_file(file)
        
        for i in load:
            for j in range(len(limit_numbers_1)):
                #[25:39,17:41]
                #[25:39,17:25]
                #[25:39,25:33]
                #[25:39,33:41]
                img = process_img( cv2.resize(i[0], (640,440), interpolation = cv2.INTER_AREA))
                
                clear_output(wait=True)
                #plt.imshow(img[25*2:39*2,17*2:41*2])
                plt.imshow(i[0])
                display(plt.show())
                display(print(j))
                plt.imshow(img[25*2:39*2,limit_numbers_1[j]*2:limit_numbers_2[j]*2])
                display(plt.show())

                ihash_1 = hash(img[25*2:39*2,limit_numbers_1[j]*2:limit_numbers_2[j]*2].tobytes())

                try:
                    display(print('valor 1 salvo:',vector_img[ihash_1][1]))
                except:
                    number = input('Digite para o valor 1: ')
                    vector_img[ihash_1] = (img[25*2:39*2,limit_numbers_1[j]*2:limit_numbers_2[j]*2].copy(),int(number))
# Out:
# None
# 1
# None
# None
# Digite para o valor 1:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-b0dbdede332d> in <module>
#      23                try:
# ---> 24                    display(print('valor 1 salvo:',vector_img[ihash_1][1]))
#      25                except:
#
# KeyError: -204938581947409628
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-b0dbdede332d> in <module>
#      25                except:
#      26                    number = input('Digite para o valor 1: ')
# ---> 27                    vector_img[ihash_1] = (img[25*2:39*2,limit_numbers_1[j]*2:limit_numbers_2[j]*2].copy(),int(number))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
save_to_file(vector_img, 'train_images_outrun_velocity.pkl')

# %%
vector_img = load_file( 'train_images_outrun_velocity.pkl')

# %%
len(vector_img.keys())
# Out:
# 1223

# %%
imgs = []
numbers = []
for i in list(vector_img.keys()):
    if vector_img[i][1] != 45 and vector_img[i][1] != 23:
        imgs.append(np.expand_dims(vector_img[i][0],axis=-1))
        numbers.append(vector_img[i][1])

# %%
pd.Series(numbers).value_counts(normalize=True)
# Out:
# 0    0.273546
# 1    0.167076
# 7    0.121212
# 2    0.075348
# 8    0.072891
# 6    0.071253
# 5    0.069615
# 9    0.053235
# 3    0.049140
# 4    0.046683
# dtype: float64

# %%
save_to_file(vector_img, 'finished_train_images_outrun_velocity.pkl')
