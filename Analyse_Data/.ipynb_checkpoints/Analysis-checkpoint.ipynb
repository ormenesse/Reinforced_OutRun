# %%
###########################
# LOADING EVDEV LIBRARIES #
###########################
import asyncio
import evdev
from evdev import list_devices, InputDevice, InputEvent, categorize, ecodes, UInput
import evdev

import pyautogui

##################################
# LOADING              LIBRARIES #
##################################


import threading
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
import mss
import sched, time
import cv2
import pickle
from multiprocessing import Process, Manager
from multiprocessing.managers import BaseManager
import subprocess
import os, sys

##################################
# LOADING DEEPLEARNING LIBRARIES #
##################################
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")

##################################
# LOADING FUNCTIONS & CLASSES    #
##################################


class CircularQueue(object):
    #Constructor
    def __init__(self,maxSize=3):
        self.queue = list()
        self.head = 0
        self.maxSize = maxSize
    #Adding elements to the queue
    def enqueue(self,data):
        if len(self.queue) >= self.maxSize:
            self.queue.pop(0)
            self.queue.append(data)
        else:
            self.queue.append(data)
        return True
    def return_queue(self):
        return self.queue

def save_to_file(objeto, nome_arquivo):
    with open(nome_arquivo, 'wb') as output:
        pickle.dump(objeto, output, pickle.HIGHEST_PROTOCOL)


def load_file(nome_arquivo):
    with open(nome_arquivo, 'rb') as input:
        objeto = pickle.load(input)
    return objeto

# %%
import re

# %%
x = re.search("^The.*Spain$", txt)

# %%
def generate_emulator_pid():

    p = subprocess.Popen(['gens','/home/ormenesse/Documents/Reinforced_Outrun/OutRun (USA, Europe).md'])
    
    # wait for the process to start
    time.sleep(0.15)

    # you gotta have xdotool installed in your machine

    output = subprocess.check_output(['xdotool','search','--pid',str(p.pid)])
    xw_id = str(output).split('\\n')[1]
    output = subprocess.run(['xwininfo','-id',xw_id],stdout=subprocess.PIPE)
    output = output.stdout.decode('utf-8')
    
    print(output)
    
    #get screens positions

    upperleftx = re.findall('Absolute upper-left X:  (\d+)',txt)[0]#int(output.split('\n')[3][-4:])
    upperlefty = re.findall('Absolute upper-left Y:  (\d+)',txt)[0]#int(output.split('\n')[4][-4:])

    # load quick save state
    
    pyautogui.press('f8')

    return p, upperleftx, upperlefty

def kill_process(p):

    p.kill()

def capture(graber,queue,positionx,positiony):

    while True:
    #print("Comecando a gavar...")
        sct_img = graber.grab({'left': positionx, 'top': positiony+40, 'width': 640, 'height': 446})
        Img = Image.frombytes('RGB', sct_img.size, sct_img.bgra, 'raw', 'BGRX')
        Img.thumbnail((320,220), Image.ANTIALIAS)
        Img = np.array(Img.convert('L')).astype(np.uint8)
        #Img = Img.T
        queue.enqueue(Img)
        time.sleep(0.15)

# %%
imgs = load_file('imgs.pkl')

# %%
plt.figure(figsize=(10,10))
plt.imshow(imgs[100][0][2])

# %%
p, upperleftx, upperlefty = generate_emulator_pid()
# Out:
# xwininfo: Window id: 0x4200003 "Gens/GS r7 - Genesis: OUTRUN"
#
#   Absolute upper-left X:  288
#   Absolute upper-left Y:  217
#   Relative upper-left X:  3
#   Relative upper-left Y:  24
#   Width: 640
#   Height: 503
#   Depth: 24
#   Visual: 0x21
#   Visual Class: TrueColor
#   Border width: 0
#   Class: InputOutput
#   Colormap: 0x20 (installed)
#   Bit Gravity State: NorthWestGravity
#   Window Gravity State: NorthWestGravity
#   Backing Store State: NotUseful
#   Save Under State: no
#   Map State: IsViewable
#   Override Redirect State: no
#   Corners:  +288+217  -282+217  -282-169  +288-169
#   -geometry 640x503+285+193

# %%
graber = mss.mss()

# %%
queue = CircularQueue(3)

# %%
capture(graber,queue,upperleftx,upperlefty)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-19aced445b6e> in <module>
# ----> 1 capture(graber,queue,upperleftx,upperlefty)
#
# <ipython-input-18-2475387d8f6e> in capture(graber, queue, positionx, positiony)
#      40         Img = Img.T
#      41         queue.enqueue(Img)
# ---> 42         time.sleep(0.15)
#
# KeyboardInterrupt:

# %%
queue.return_queue()
# Out:
# [array([[82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         ...,
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98]], dtype=uint8),
#  array([[82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         ...,
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98]], dtype=uint8),
#  array([[82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         ...,
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98],
#         [82, 82, 82, ..., 98, 98, 98]], dtype=uint8)]

# %%
plt.figure(figsize=(10,10))
plt.imshow(queue.return_queue()[0])
